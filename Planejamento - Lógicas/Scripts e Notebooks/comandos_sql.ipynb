# %%
# Imports dos Pacotes:
from datetime import date
from numpy import random
import sqlite3 

# path_inputs_forms
# ìnicia conexão com o banco:
_conn = sqlite3.connect('Forms/Oferta Disponivel.db')

# Percorre colunas da tabela para joins:
_period_columns_string = ', '.join([f'A.{semanas}' for semanas in periodos_form_semanas])

# _query variável para comando SQL:
_query = f"""
          SELECT name FROM sqlite_master WHERE type='table';
          """
# Verificação de conexão com o banco:
if _conn:
    # _cur = _conn.cursor()
    print(f"Conectado")
    # data = cur.execute(_query)
    # _cur.executemany(_query, _query)
    # for valor in data:
    #     print(valor)
    print(f"Comando SQL - Executado")
    _df = pd.read_sql_query(_query,_conn)
    # Encerra conexão com o banco:
    _conn.close()
else: print(f"Comando não Excutado")

result = _df

## COMANDOS SQL

# Alterar nome da coluna:
# ALTER TABLE ic_form_marcha RENAME COLUMN Dia_06 TO Sem_06;

# Selecionar todos os dados:
# SELECT * FROM ic_form_marcha;

# Verificando a versão do banco:
# Select sqlite_version();

# Consultando as tabelas do banco:
# SELECT name FROM sqlite_master WHERE type='table';

# Deletar tabelas:
# DROP TABLE ic_entity_unidades;

## TABELAS ATUAIS:
#                                  name

# 0                     sqlite_sequence
# 1                             _users_
# 2                  ic_entity_fabricas -- ic_entity_fabricas
# 3              ic_entity_cod_unidades -- ic_entity_cod_unidades
# 4         ic_entity_prod_equipamentos -- ic_entity_prod_equipamentos
# 5   ic_form_disponibilidade_projetada -- ic_form_disponibilidade_projetada
# 6       ic_form_performance_projetada -- ic_form_performance_projetada
# 7               ic_entity_tipo_marcha -- ic_entity_tipo_marcha
# 8                      ic_form_marcha -- ic_form_marcha

# %%
# Imports dos Pacotes:
from datetime import date
from numpy import random
import sqlite3 

# path_inputs_forms
# ìnicia conexão com o banco:
_conn = sqlite3.connect('Forms/Oferta Disponivel.db')

# Percorre colunas da tabela para joins:
_period_columns_string = ', '.join([f'A.{semanas}' for semanas in periodos_form_semanas])

# _query variável para comando SQL:
_query = f"""
          SELECT * FROM ic_entity_fabricas;
          """
# Verificação de conexão com o banco:
if _conn:
    # _cur = _conn.cursor()
    print(f"Conectado")
    # data = cur.execute(_query)
    # _cur.executemany(_query, _query)
    # for valor in data:
    #     print(valor)
    print(f"Comando SQL - Executado")
    _df = pd.read_sql_query(_query,_conn)
    # Encerra conexão com o banco:
    _conn.close()
else: print(f"Comando não Excutado")

result = _df

# %%
# # Trocando nomes de Periods Para datas com função rename
# _df = _df.rename( columns = {
#     'Fabricas':'Fabricas', 
#     'Codigo_Unidades':'Codigo_Unidades', 
#     'Equipamentos':'Equipamentos', 
#     'Comentários':'Comentários',
#     'Period_001':'2021-01',
#     'Period_002':'2021-02',
#     'Period_003':'2021-03',
#     'Period_004':'2021-04',
#     'Period_005':'2021-05',
#     'Period_006':'2021-06',
#     'Period_007':'2021-07',
#     'Period_008':'2021-08',
#     'Period_009':'2021-09',
#     'Period_010':'2021-10',
#     'Period_011':'2021-11',
#     'Period_012':'2021-12',
#     'Period_013':'2022-01',
#     'Period_014':'2022-02',
#     'Period_015':'2022-03',
#     'Period_016':'2022-04',
#     'Period_017':'2022-05',
#     'Period_018':'2022-06',
#     'Period_019':'2022-07',
#     'Period_020':'2022-08',
#     'Period_021':'2022-09',
#     'Period_022':'2022-10',
#     'Period_023':'2022-11',
#     'Period_024':'2022-12'
# } )

# # Trocando nomes de Periods Para datas com for
# _colunas = _df.columns.to_list()
# for col in range(len(_colunas)) :
#     if col > 3:
#         _df.columns.values[col] = _list_periods[col-4]
#         # print(_df.columns[col])
#         # print(_list_periods[col-4])
