# %% [markdown]
# #### Pacotes

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Exemplo curva ABC

# %%
data = {
    'pais':['BRASIL','BRASIL','BRASIL', 'PERU','PERU','PERU'],
    'cod_produto':['1','2','3','10','20','30'],
    'receita': [5085,100,5655,451,456,458]
}

_df = pd.DataFrame(data)
_df
# Out:
#      pais cod_produto  receita
# 0  BRASIL           1     5085
# 1  BRASIL           2      100
# 2  BRASIL           3     5655
# 3    PERU          10      451
# 4    PERU          20      456
# 5    PERU          30      458

# %% [markdown]
# #### Ranqueando por receita

# %%
_df = _df.groupby(['pais', 'cod_produto'], as_index=False).agg({'receita':sum}) # quando os dados estiverem mais granulares.
_df = _df.sort_values(['pais', 'receita'], ascending=False,)
_df
# Out:
#      pais cod_produto  receita
# 5    PERU          30      458
# 4    PERU          20      456
# 3    PERU          10      451
# 2  BRASIL           3     5655
# 0  BRASIL           1     5085
# 1  BRASIL           2      100

# %% [markdown]
# #### Fanzendo o share por pais

# %%
_df_sum = _df.groupby(['pais'], as_index=False).agg({'receita':sum}).rename(columns={'receita':'receita_sum'})

_df = _df.merge(_df_sum, on=['pais'], how= 'left')

_df['share'] = np.where(_df['receita_sum'] == 0, 0,_df['receita']/_df['receita_sum'])

_df
# Out:
#      pais cod_produto  receita  receita_sum     share
# 0    PERU          30      458         1365  0.335531
# 1    PERU          20      456         1365  0.334066
# 2    PERU          10      451         1365  0.330403
# 3  BRASIL           3     5655        10840  0.521679
# 4  BRASIL           1     5085        10840  0.469096
# 5  BRASIL           2      100        10840  0.009225

# %% [markdown]
# #### Fazendo a soma acumulativa (cumsum)

# %%
_df['cumsum'] = _df.groupby(['pais']).agg({'share':'cumsum'})
_df
# Out:
#      pais cod_produto  receita  receita_sum     share    cumsum
# 0    PERU          30      458         1365  0.335531  0.335531
# 1    PERU          20      456         1365  0.334066  0.669597
# 2    PERU          10      451         1365  0.330403  1.000000
# 3  BRASIL           3     5655        10840  0.521679  0.521679
# 4  BRASIL           1     5085        10840  0.469096  0.990775
# 5  BRASIL           2      100        10840  0.009225  1.000000

# %% [markdown]
# #### Regra Curva ABC

# %%
"""
Regra 
Se CumSum(Valor Acumudado do share) <= 80% classe_abc = A 
Se CumSum(Valor Acumudado do share) > 80% e CumSum(Valor Acumudado do share) <= A80% + B15% classe_abc = B
Se não classe_abc = C
"""

_df['classe_abc'] = np.where(_df['cumsum'] <= 0.60, 'A', 
                    np.where( (_df['cumsum'] > 0.60 ) & (_df['cumsum'] <= 0.80), 'B', 'C'))

_df
# Out:
#      pais cod_produto  receita  receita_sum     share    cumsum classe_abc
# 0    PERU          30      458         1365  0.335531  0.335531          A
# 1    PERU          20      456         1365  0.334066  0.669597          B
# 2    PERU          10      451         1365  0.330403  1.000000          C
# 3  BRASIL           3     5655        10840  0.521679  0.521679          A
# 4  BRASIL           1     5085        10840  0.469096  0.990775          C
# 5  BRASIL           2      100        10840  0.009225  1.000000          C

# %%
def highlight_cols(s):
    if s == 'A':
        color = 'green'
    elif s == 'B':
        color = 'blue'
    else:
        color = 'red'
    return 'background-color: % s' % color

# %%
_df.style.format( '{:.2f}', subset=['share', 'cumsum'] ) \
    .background_gradient(subset=['share', 'cumsum'] , cmap='Reds')\
    .applymap(highlight_cols, subset =['classe_abc'])
    # .applymap(lambda x: 'color:black;', subset =['classe_abc'])
# Out:
# <style type="text/css">
# #T_338ed_row0_col4 {
#   background-color: #eb372a;
#   color: #f1f1f1;
# }
# #T_338ed_row0_col5, #T_338ed_row5_col4 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_338ed_row0_col6, #T_338ed_row3_col6 {
#   background-color: green;
# }
# #T_338ed_row1_col4 {
#   background-color: #ec382b;
#   color: #f1f1f1;
# }
# #T_338ed_row1_col5 {
#   background-color: #fb694a;
#   color: #f1f1f1;
# }
# #T_338ed_row1_col6 {
#   background-color: blue;
# }
# #T_338ed_row2_col4 {
#   background-color: #ee3a2c;
#   color: #f1f1f1;
# }
# #T_338ed_row2_col5, #T_338ed_row3_col4, #T_338ed_row5_col5 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_338ed_row2_col6, #T_338ed_row4_col6, #T_338ed_row5_col6 {
#   background-color: red;
# }
# #T_338ed_row3_col5 {
#   background-color: #fcb296;
#   color: #000000;
# }
# #T_338ed_row4_col4 {
#   background-color: #9a0c14;
#   color: #f1f1f1;
# }
# #T_338ed_row4_col5 {
#   background-color: #6d010e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_338ed_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >pais</th>
#       <th class="col_heading level0 col1" >cod_produto</th>
#       <th class="col_heading level0 col2" >receita</th>
#       <th class="col_heading level0 col3" >receita_sum</th>
#       <th class="col_heading level0 col4" >share</th>
#       <th class="col_heading level0 col5" >cumsum</th>
#       <th class="col_heading level0 col6" >classe_abc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_338ed_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_338ed_row0_col0" class="data row0 col0" >PERU</td>
#       <td id="T_338ed_row0_col1" class="data row0 col1" >30</td>
#       <td id="T_338ed_row0_col2" class="data row0 col2" >458</td>
#       <td id="T_338ed_row0_col3" class="data row0 col3" >1365</td>
#       <td id="T_338ed_row0_col4" class="data row0 col4" >0.34</td>
#       <td id="T_338ed_row0_col5" class="data row0 col5" >0.34</td>
#       <td id="T_338ed_row0_col6" class="data row0 col6" >A</td>
#     </tr>
#     <tr>
#       <th id="T_338ed_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_338ed_row1_col0" class="data row1 col0" >PERU</td>
#       <td id="T_338ed_row1_col1" class="data row1 col1" >20</td>
#       <td id="T_338ed_row1_col2" class="data row1 col2" >456</td>
#       <td id="T_338ed_row1_col3" class="data row1 col3" >1365</td>
#       <td id="T_338ed_row1_col4" class="data row1 col4" >0.33</td>
#       <td id="T_338ed_row1_col5" class="data row1 col5" >0.67</td>
#       <td id="T_338ed_row1_col6" class="data row1 col6" >B</td>
#     </tr>
#     <tr>
#       <th id="T_338ed_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_338ed_row2_col0" class="data row2 col0" >PERU</td>
#       <td id="T_338ed_row2_col1" class="data row2 col1" >10</td>
#       <td id="T_338ed_row2_col2" class="data row2 col2" >451</td>
#       <td id="T_338ed_row2_col3" class="data row2 col3" >1365</td>
#       <td id="T_338ed_row2_col4" class="data row2 col4" >0.33</td>
#       <td id="T_338ed_row2_col5" class="data row2 col5" >1.00</td>
#       <td id="T_338ed_row2_col6" class="data row2 col6" >C</td>
#     </tr>
#     <tr>
#       <th id="T_338ed_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_338ed_row3_col0" class="data row3 col0" >BRASIL</td>
#       <td id="T_338ed_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_338ed_row3_col2" class="data row3 col2" >5655</td>
#       <td id="T_338ed_row3_col3" class="data row3 col3" >10840</td>
#       <td id="T_338ed_row3_col4" class="data row3 col4" >0.52</td>
#       <td id="T_338ed_row3_col5" class="data row3 col5" >0.52</td>
#       <td id="T_338ed_row3_col6" class="data row3 col6" >A</td>
#     </tr>
#     <tr>
#       <th id="T_338ed_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_338ed_row4_col0" class="data row4 col0" >BRASIL</td>
#       <td id="T_338ed_row4_col1" class="data row4 col1" >1</td>
#       <td id="T_338ed_row4_col2" class="data row4 col2" >5085</td>
#       <td id="T_338ed_row4_col3" class="data row4 col3" >10840</td>
#       <td id="T_338ed_row4_col4" class="data row4 col4" >0.47</td>
#       <td id="T_338ed_row4_col5" class="data row4 col5" >0.99</td>
#       <td id="T_338ed_row4_col6" class="data row4 col6" >C</td>
#     </tr>
#     <tr>
#       <th id="T_338ed_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_338ed_row5_col0" class="data row5 col0" >BRASIL</td>
#       <td id="T_338ed_row5_col1" class="data row5 col1" >2</td>
#       <td id="T_338ed_row5_col2" class="data row5 col2" >100</td>
#       <td id="T_338ed_row5_col3" class="data row5 col3" >10840</td>
#       <td id="T_338ed_row5_col4" class="data row5 col4" >0.01</td>
#       <td id="T_338ed_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_338ed_row5_col6" class="data row5 col6" >C</td>
#     </tr>
#   </tbody>
# </table>
